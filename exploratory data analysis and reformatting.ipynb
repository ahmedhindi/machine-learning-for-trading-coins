# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('ETC.csv', parse_dates=True)

# %%
data[:25].to_csv('sample.csv')

# %%
data.dtypes
# Out:
# PrevDay           float64
# OpenSellOrders      int64
# Volume            float64
# Last              float64
# Created            object
# TimeStamp          object
# Bid               float64
# OpenBuyOrders       int64
# High              float64
# MarketName         object
# Low               float64
# Ask               float64
# BaseVolume        float64
# dtype: object

# %%
data.head()
# Out:
#     PrevDay  OpenSellOrders        Volume      Last                 Created  \
# 0  0.002493             941  37046.988183  0.002526  2016-07-26T18:10:22.82
# 1  0.002493             940  37046.988183  0.002526  2016-07-26T18:10:22.82
# 2  0.002493             940  37046.988183  0.002526  2016-07-26T18:10:22.82
# 3  0.002493             940  37046.988183  0.002526  2016-07-26T18:10:22.82
# 4  0.002493             940  37046.988183  0.002526  2016-07-26T18:10:22.82
#
#                  TimeStamp       Bid  OpenBuyOrders      High MarketName  \
# 0  2017-04-01T17:17:13.333  0.002537            313  0.002647    BTC-ETC
# 1   2017-04-01T17:18:05.63  0.002537            315  0.002647    BTC-ETC
# 2   2017-04-01T17:18:09.71  0.002537            316  0.002647    BTC-ETC
# 3    2017-04-01T17:19:08.1  0.002538            314  0.002647    BTC-ETC
# 4   2017-04-01T17:20:10.96  0.002539            313  0.002647    BTC-ETC
#
#         Low       Ask  BaseVolume
# 0  0.002493  0.002572   94.691996
# 1  0.002493  0.002572   94.691996
# 2  0.002493  0.002572   94.691996
# 3  0.002493  0.002572   94.691996
# 4  0.002493  0.002572   94.691996

# %%
data.columns = data.columns.str.lower()

# %%
data['timestamp'] = pd.to_datetime(data.timestamp)

# %%
data['created'] = pd.to_datetime(data.created)

# %%
data.set_index('timestamp', inplace=True)
scscsedfsdf

# %%
data['n'] = 1

# %% [markdown]
# ### the number of data points per day

# %%
data.resample('d').n.count().plot()
plt.ylabel('the number of data points per day')
plt.xlabel('time');

# %% [markdown]
# ### the diffrance between bid and ask

# %%
(data.ask - data.bid).plot(figsize=(15,5))
plt.xlabel('the diffrance between bid and ask') ;

# %%
data[['ask','bid']].plot(figsize=(15,7), linestyle='dashed')
plt.xlabel(' ');

# %% [markdown]
# ## the volume for every day in the month

# %%
data.resample('d').basevolume.mean().plot(kind='bar', figsize=(15,6));

# %%
f = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
days = np.array(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# %% [markdown]
# ## the volume grouped by day

# %%
data.groupby(data.index.dayofweek)['basevolume'].sum().plot(kind='bar' ,figsize=(12,5),color=f)
plt.xticks(np.arange(8),days);

# %% [markdown]
# ## the volume grouped by hour

# %%
data.groupby(data.index.hour)['basevolume'].sum().plot(linestyle='dashed' ,figsize=(12,5));

# %%
data['hl_diff'] = data.high - data.low

# %% [markdown]
# ## the change of the diffrance between thw high and low over the month

# %%
data.hl_diff.plot(figsize=(15,5))
plt.xlabel(' ');

# %%
data.resample("d").hl_diff.mean().plot(figsize=(15,5));

# %%
data['next'] = data.ask.shift(1)

# %%
data['change'] = (data.next - data.ask)

# %% [markdown]
# ### the averages movement

# %%
np.abs(data.change.mean())
# Out:
# 4.9786739954834044e-08

# %%
def up_down(row):
    if row > 0:
        return 'up'
    elif row < 0:
        return 'down'
    else:
        return np.nan

# %%
data['up_down'] = data.change.apply(up_down)

# %%
data.up_down.value_counts()
# Out:
# up      27785
# down     5732
# Name: up_down, dtype: int64

# %% [markdown]
# ## up & down movments

# %%
data.up_down.value_counts().plot(kind='bar')

# %%
data.ask.plot()

# %%
data.change.plot(figsize=(12,7))

# %%
data[['ask','next']][600:700].plot(figsize=(15,7))

# %%
sns.distplot(np.abs(data.change.dropna()),kde=True,)

# %% [markdown]
# ### SMA

# %%
data['sma_5'] = data['ask'].rolling(5).mean()
data['sma_10'] = data['ask'].rolling(10).mean()
data['sma_20'] = data['ask'].rolling(20).mean()

# %%
data[['sma_5','sma_10','sma_20']][:500].plot(figsize=(20,5),alpha=0.8)
data['ask'][:500].plot(linestyle='dashed')

# %%
cmap = sns.diverging_palette(10, 1, as_cmap=True)
sns.heatmap(data[['sma_5','sma_10','sma_20']].corr(),annot=True,cmap=cmap)

# %%
data = data.dropna()

# %%
data['pc_ch_5'] = data.sma_5.pct_change()

# %%
data['pc_ch_10'] = data.sma_10.pct_change()

# %%
data['pc_ch_20'] = data.sma_20.pct_change()

# %%
data[['change','pc_ch_20']][15:100].plot()

# %%
data.head()
# Out:
#                           prevday  opensellorders        volume      last  \
# timestamp
# 2017-04-01 17:34:47.610  0.002550             941  36973.670938  0.002550
# 2017-04-01 17:45:10.017  0.002596             941  37103.433177  0.002538
# 2017-04-01 17:47:11.330  0.002596             945  37102.998832  0.002538
# 2017-04-01 17:48:06.080  0.002596             946  37102.998832  0.002538
# 2017-04-01 17:49:12.203  0.002596             946  37055.298095  0.002538
#
#                                         created       bid  openbuyorders  \
# timestamp
# 2017-04-01 17:34:47.610 2016-07-26 18:10:22.820  0.002550            320
# 2017-04-01 17:45:10.017 2016-07-26 18:10:22.820  0.002539            317
# 2017-04-01 17:47:11.330 2016-07-26 18:10:22.820  0.002540            319
# 2017-04-01 17:48:06.080 2016-07-26 18:10:22.820  0.002540            316
# 2017-04-01 17:49:12.203 2016-07-26 18:10:22.820  0.002536            318
#
#                              high marketname     low    ...     n  \
# timestamp                                               ...
# 2017-04-01 17:34:47.610  0.002647    BTC-ETC  0.0025    ...     1
# 2017-04-01 17:45:10.017  0.002647    BTC-ETC  0.0025    ...     1
# 2017-04-01 17:47:11.330  0.002647    BTC-ETC  0.0025    ...     1
# 2017-04-01 17:48:06.080  0.002647    BTC-ETC  0.0025    ...     1
# 2017-04-01 17:49:12.203  0.002647    BTC-ETC  0.0025    ...     1
#
#                                change      next  up_down     sma_5    sma_20  \
# timestamp
# 2017-04-01 17:34:47.610  1.099000e-05  0.002571       up  0.002571  0.002573
# 2017-04-01 17:45:10.017 -8.000000e-08  0.002560     down  0.002560  0.002569
# 2017-04-01 17:47:11.330  8.000000e-08  0.002560       up  0.002560  0.002568
# 2017-04-01 17:48:06.080 -8.000000e-08  0.002560     down  0.002560  0.002567
# 2017-04-01 17:49:12.203  8.000000e-08  0.002560       up  0.002560  0.002567
#
#                            sma_10   pc_ch_5  pc_ch_10  pc_ch_20
# timestamp
# 2017-04-01 17:34:47.610  0.002574       NaN       NaN       NaN
# 2017-04-01 17:45:10.017  0.002564 -0.004257 -0.003896 -0.001409
# 2017-04-01 17:47:11.330  0.002561  0.000006 -0.001080 -0.000440
# 2017-04-01 17:48:06.080  0.002560  0.000006 -0.000426 -0.000213
# 2017-04-01 17:49:12.203  0.002560  0.000000  0.000000 -0.000211
#
# [5 rows x 22 columns]

# %%
data['sma5_ask_diff'] = (data.sma_5  - data.ask)

# %%
data['sma10_ask_diff'] = (data.sma_10  - data.ask)

# %%
data['sma20_ask_diff'] = (data.sma_20  - data.ask)

# %%
data[['change','sma5_ask_diff']][5000:10000].plot(alpha=0.8, figsize=(17,5));

# %%
data[['change','sma10_ask_diff']][5000:10000].plot(alpha=0.8, figsize=(17,5));

# %%
data[['change','sma20_ask_diff']][5000:10000].plot(alpha=0.8, figsize=(17,5));

# %%
data.columns
# Out:
# Index(['prevday', 'opensellorders', 'volume', 'last', 'created', 'bid',
#        'openbuyorders', 'high', 'marketname', 'low', 'ask', 'basevolume', 'n',
#        'change', 'next', 'up_down', 'sma_5', 'sma_20', 'sma_10', 'pc_ch_5',
#        'pc_ch_10', 'pc_ch_20', 'sma_ask_diff', 'sma5_ask_diff',
#        'sma10_ask_diff', 'sma20_ask_diff'],
#       dtype='object')

# %%
data[['sma20_ask_diff','sma_20']][:10]
# Out:
#                          sma20_ask_diff    sma_20
# timestamp
# 2017-04-01 17:34:47.610        0.000013  0.002573
# 2017-04-01 17:45:10.017        0.000009  0.002569
# 2017-04-01 17:47:11.330        0.000008  0.002568
# 2017-04-01 17:48:06.080        0.000007  0.002567
# 2017-04-01 17:49:12.203        0.000007  0.002567
# 2017-04-01 17:53:10.160        0.000008  0.002563
# 2017-04-01 18:04:07.663        0.000004  0.002557
# 2017-04-01 18:05:10.773        0.000001  0.002557
# 2017-04-01 18:09:07.820       -0.000020  0.002557
# 2017-04-01 18:10:35.777       -0.000018  0.002559

# %%
plt.figure(1,figsize=(15,5))
plt.subplot(311)
plt.plot(data.sma20_ask_diff[20:800])

plt.subplot(312)
plt.plot(data.sma_20[20:800], 'r--')


plt.subplot(313)
plt.plot(data.ask[20:800], '--')
plt.xlabel('plotting the diffrance between the percentage change ')

plt.show()

# %%
data.columns
# Out:
# Index(['prevday', 'opensellorders', 'volume', 'last', 'created', 'bid',
#        'openbuyorders', 'high', 'marketname', 'low', 'ask', 'basevolume', 'n',
#        'hl_diff', 'next', 'change', 'up_down', 'sma_5', 'sma_10', 'sma_20',
#        'pc_ch_5', 'pc_ch_10', 'pc_ch_20', 'sma5_ask_diff', 'sma10_ask_diff',
#        'sma20_ask_diff'],
#       dtype='object')

# %%
data['spread'] = data.high - data.low

# %%
plt.figure(1)
plt.subplot(211)
data['basevolume'].plot()

plt.subplot(212)
data.volume.plot()

# %%
to_drop = ['timestamp','prevday','opensellorders','last','created','bid','openbuyorders','marketname','low','n','high','basevolume']
data.drop(to_drop,axis=1,inplace=True)

data.dropna(inplace=True)

data['up_down'] = data.up_down.map({'up':1,'down':0})

# %%
y = data.up_down.to_csv('y.csv')
data.drop('up_down',axis=1,inplace=True)
X = data.to_csv('X.csv')
